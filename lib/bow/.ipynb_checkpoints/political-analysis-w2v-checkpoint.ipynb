# %%
import pandas as pd
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/l4/twlnrt1s2fb8mghf2jqh1lfr0000gn/T/ipykernel_47048/2972731726.py in <module>
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from gensim.models import Word2Vec
#
# /opt/anaconda3/lib/python3.9/site-packages/gensim/__init__.py in <module>
#       9 import logging
#      10
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      12
#      13
#
# /opt/anaconda3/lib/python3.9/site-packages/gensim/parsing/__init__.py in <module>
#       2
#       3 from .porter import PorterStemmer  # noqa:F401
# ----> 4 from .preprocessing import (  # noqa:F401
#       5     preprocess_documents,
#       6     preprocess_string,
#
# /opt/anaconda3/lib/python3.9/site-packages/gensim/parsing/preprocessing.py in <module>
#      24 import glob
#      25
# ---> 26 from gensim import utils
#      27 from gensim.parsing.porter import PorterStemmer
#      28
#
# /opt/anaconda3/lib/python3.9/site-packages/gensim/utils.py in <module>
#      34 import numpy as np
#      35 import scipy.sparse
# ---> 36 from smart_open import open
#      37
#      38 from gensim import __version__ as gensim_version
#
# /opt/anaconda3/lib/python3.9/site-packages/smart_open/__init__.py in <module>
#      32
#      33 from smart_open import version  # noqa: E402
# ---> 34 from .smart_open_lib import open, parse_uri, smart_open, register_compressor  # noqa: E402
#      35
#      36 _WARNING = """smart_open.s3_iter_bucket is deprecated and will stop functioning
#
# /opt/anaconda3/lib/python3.9/site-packages/smart_open/smart_open_lib.py in <module>
#      33 import smart_open.compression as so_compression
#      34
# ---> 35 from smart_open import doctools
#      36 from smart_open import transport
#      37
#
# /opt/anaconda3/lib/python3.9/site-packages/smart_open/doctools.py in <module>
#      19
#      20 from . import compression
# ---> 21 from . import transport
#      22
#      23 PLACEHOLDER = '    smart_open/doctools.py magic goes here'
#
# /opt/anaconda3/lib/python3.9/site-packages/smart_open/transport.py in <module>
#      96 register_transport(smart_open.local_file)
#      97 register_transport('smart_open.azure')
# ---> 98 register_transport('smart_open.gcs')
#      99 register_transport('smart_open.hdfs')
#     100 register_transport('smart_open.http')
#
# /opt/anaconda3/lib/python3.9/site-packages/smart_open/transport.py in register_transport(submodule)
#      47     if isinstance(submodule, str):
#      48         try:
# ---> 49             submodule = importlib.import_module(submodule)
#      50         except ImportError:
#      51             return
#
# /opt/anaconda3/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /opt/anaconda3/lib/python3.9/site-packages/smart_open/gcs.py in <module>
#      14 try:
#      15     import google.cloud.exceptions
# ---> 16     import google.cloud.storage
#      17     import google.auth.transport.requests
#      18 except ImportError:
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/storage/__init__.py in <module>
#      37 __version__ = get_distribution("google-cloud-storage").version
#      38
# ---> 39 from google.cloud.storage.batch import Batch
#      40 from google.cloud.storage.blob import Blob
#      41 from google.cloud.storage.bucket import Bucket
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/storage/batch.py in <module>
#      27 import six
#      28
# ---> 29 from google.cloud import _helpers
#      30 from google.cloud import exceptions
#      31 from google.cloud.storage._http import Connection
#
# /opt/anaconda3/lib/python3.9/site-packages/google/cloud/_helpers.py in <module>
#      31 import google.auth
#      32 import google.auth.transport.requests
# ---> 33 from google.protobuf import duration_pb2
#      34 from google.protobuf import timestamp_pb2
#      35
#
# /opt/anaconda3/lib/python3.9/site-packages/google/protobuf/duration_pb2.py in <module>
#       3 # source: google/protobuf/duration.proto
#       4 """Generated protocol buffer code."""
# ----> 5 from google.protobuf import descriptor as _descriptor
#       6 from google.protobuf import descriptor_pool as _descriptor_pool
#       7 from google.protobuf import symbol_database as _symbol_database
#
# /opt/anaconda3/lib/python3.9/site-packages/google/protobuf/descriptor.py in <module>
#      38 import warnings
#      39
# ---> 40 from google.protobuf.internal import api_implementation
#      41
#      42 _USE_C_DESCRIPTORS = False
#
# /opt/anaconda3/lib/python3.9/site-packages/google/protobuf/internal/api_implementation.py in <module>
#     102   try:
#     103     # pylint: disable=g-import-not-at-top
# --> 104     from google.protobuf.pyext import _message
#     105     sys.modules['google3.net.proto2.python.internal.cpp._message'] = _message
#     106     _c_module = _message
#
# TypeError: bases must be types

# %%
development = pd.read_csv("development.csv")

# %%
model = Word2Vec(sentences=development['tweet'], vector_size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")
